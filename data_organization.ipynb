# %%
import json

# %%
file = "NEW_AIGeneratedData_json/sifted_final_merged_lessons_with_mcqs_16Jan 25, 2026_153124_randomized_16Jan_161140"

# %%
with open(file, "r") as f:
    data = json.load(f)

# %%
titles = [item["title"] for item in data]
titles
# Out:
# ['Randomization',
#  'Endnote',
#  'String Methods',
#  'What-Is-Data-Science',
#  'Names',
#  'Establishing-Causality',
#  'Computational-Tools',
#  'Data Types',
#  'Expressions',
#  'Plotting the Classics',
#  'Causality-And-Experiments',
#  'Comparisons',
#  'Introduction to Tables',
#  'Strings',
#  'Intro',
#  'Another Kind Of Character',
#  'Why-Data-Science',
#  'Numbers',
#  'Statistical-Techniques',
#  'Programming-In-Python',
#  'Example: Growth Rates',
#  'Call Expressions']

# %%
topics = [item["topic"] for item in data]
topics
# Out:
# ['Data Science',
#  'Data Science',
#  'Data Science',
#  'Data Science',
#  'Data Science',
#  'Causality',
#  'Python',
#  'Data Science',
#  'Data Science',
#  'Visualization',
#  'Causality',
#  'Data Science',
#  'Data',
#  'Data Science',
#  'Data Science',
#  'Data Science',
#  'Data Science',
#  'Data Science',
#  'Data Science',
#  'Python',
#  'Data Science',
#  'Data Science']

# %%
set(topics)
# Out:
# {'Causality', 'Data', 'Data Science', 'Python', 'Visualization'}

# %%
with open("data_scraping/levels/level_1.json", "r") as f:
    level_data = json.load(f)

# %%
level_titles = {item['id']: item["title"] for item in level_data}
level_titles
# Out:
# {1295251401: 'Computational-Tools',
#  3685813449: 'Statistical-Techniques',
#  2727718540: 'Intro',
#  2888989471: 'Why-Data-Science',
#  2439779044: 'Literary Characters',
#  2768641799: 'Another Kind Of Character',
#  1930966851: 'Plotting the Classics',
#  781822617: 'What-Is-Data-Science',
#  3264203265: 'Observation-And-Visualization-John-Snow-And-The-Broad-Street-Pump',
#  1628354092: 'Snow-S-Grand-Experiment',
#  1251066844: 'Establishing-Causality',
#  157990508: 'Randomization',
#  289240178: 'Endnote',
#  2027312779: 'Causality-And-Experiments',
#  1739879824: 'Expressions',
#  4008464310: 'Example: Growth Rates',
#  1176507067: 'Names',
#  4042898330: 'Call Expressions',
#  2427013110: 'Introduction to Tables',
#  3891774532: 'Programming-In-Python',
#  3082398315: 'Numbers',
#  663140214: 'String Methods',
#  2697797242: 'Strings',
#  2089344509: 'Comparisons',
#  1320813483: 'Data Types',
#  885316205: 'Intro'}

# %%
titles
# Out:
# ['Randomization',
#  'Endnote',
#  'String Methods',
#  'What-Is-Data-Science',
#  'Names',
#  'Establishing-Causality',
#  'Computational-Tools',
#  'Data Types',
#  'Expressions',
#  'Plotting the Classics',
#  'Causality-And-Experiments',
#  'Comparisons',
#  'Introduction to Tables',
#  'Strings',
#  'Intro',
#  'Another Kind Of Character',
#  'Why-Data-Science',
#  'Numbers',
#  'Statistical-Techniques',
#  'Programming-In-Python',
#  'Example: Growth Rates',
#  'Call Expressions']

# %%
# order of titles with ids in accordance w/ textbook
{
    781822617: 'What-Is-Data-Science',
    2727718540: 'Intro',
    1295251401: 'Computational-Tools',
    3685813449: 'Statistical-Techniques',
    2888989471: 'Why-Data-Science',
    1930966851: 'Plotting the Classics',
    2768641799: 'Another Kind Of Character',

    2027312779: 'Causality-And-Experiments',
    1251066844: 'Establishing-Causality',
    157990508: 'Randomization',
    289240178: 'Endnote',

    3891774532: 'Programming-In-Python',
    1739879824: 'Expressions',
    1176507067: 'Names',
    4008464310: 'Example: Growth Rates',
    4042898330: 'Call Expressions',
    2427013110: 'Introduction to Tables',

    1320813483: 'Data Types',
    3082398315: 'Numbers',
    2697797242: 'Strings',
    663140214: 'String Methods',
    2089344509: 'Comparisons',
}
