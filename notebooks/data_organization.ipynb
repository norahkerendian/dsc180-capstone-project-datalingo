# %%
import json

# %%
file = "../NEW_AIGeneratedData_json/merged_lessons_with_mcqs_level2_22Feb 22, 2026_131617_randomized_22Feb_134240.json"

# %%
with open(file, "r") as f:
    data = json.load(f)

# %%
titles = [item["title"] for item in data]
titles
# Out:
# ['Overlaid Graphs',
#  'Sorting Rows',
#  'Visualizing Categorical Distributions',
#  'Classifying by One Variable',
#  'Sequences',
#  'Joining Tables by Columns',
#  'Functions and Tables',
#  'Tables',
#  'Cross-Classifying by More than One Variable',
#  'Visualizing Numerical Distributions',
#  'More on Arrays',
#  'Applying a Function to a Column',
#  'Selecting Rows',
#  'Visualization',
#  'Arrays',
#  'Ranges']

# %%
topics = [item["topic"] for item in data]
topics
# Out:
# ['Data Science',
#  'Data Science',
#  'Visualization',
#  'Data Science',
#  'Data Science',
#  'Data',
#  'Data',
#  'Data',
#  'Data Science',
#  'Visualization',
#  'Data Science',
#  'Data Science',
#  'Data Science',
#  'Visualization',
#  'Data Science',
#  'Data Science']

# %%
set(topics)
# Out:
# {'Data', 'Data Science', 'Visualization'}

# %%
with open("../data_scraping/levels/level_2.json", "r") as f:
    level_data = json.load(f)

# %%
level_titles = {item['id']: item["title"] for item in level_data}
level_titles
# Out:
# {4182291720: 'Arrays',
#  4206554089: 'Ranges',
#  3620647107: 'More on Arrays',
#  865601147: 'Sequences',
#  328304638: 'Sorting Rows',
#  3878803103: 'Selecting Rows',
#  2933191412: 'Example: Population Trends',
#  2793681157: 'Example: Sex Ratios',
#  3053275831: 'Tables',
#  332165191: 'Visualizing Categorical Distributions',
#  3378221435: 'Visualizing Numerical Distributions',
#  113008979: 'Overlaid Graphs',
#  4146444081: 'Visualization',
#  3756949322: 'Applying a Function to a Column',
#  647528902: 'Classifying by One Variable',
#  3324962146: 'Cross-Classifying by More than One Variable',
#  881925579: 'Joining Tables by Columns',
#  2991001592: 'Bike Sharing in the Bay Area',
#  2691935601: 'Functions and Tables'}

# %%
titles
# Out:
# ['Overlaid Graphs',
#  'Sorting Rows',
#  'Visualizing Categorical Distributions',
#  'Classifying by One Variable',
#  'Sequences',
#  'Joining Tables by Columns',
#  'Functions and Tables',
#  'Tables',
#  'Cross-Classifying by More than One Variable',
#  'Visualizing Numerical Distributions',
#  'More on Arrays',
#  'Applying a Function to a Column',
#  'Selecting Rows',
#  'Visualization',
#  'Arrays',
#  'Ranges']

# %%
# order of titles with ids in accordance w/ textbook
# level 2
{
    865601147: 'Sequences',
    4182291720: 'Arrays',
    4206554089: 'Ranges',
    3620647107: 'More on Arrays',

    3053275831: 'Tables',
    328304638: 'Sorting Rows',
    3878803103: 'Selecting Rows',

    4146444081: 'Visualization',
    332165191: 'Visualizing Categorical Distributions',
    3378221435: 'Visualizing Numerical Distributions',
    113008979: 'Overlaid Graphs',
    
    2691935601: 'Functions and Tables',
    3756949322: 'Applying a Function to a Column',
    647528902: 'Classifying by One Variable',
    3324962146: 'Cross-Classifying by More than One Variable',
    881925579: 'Joining Tables by Columns'
}
